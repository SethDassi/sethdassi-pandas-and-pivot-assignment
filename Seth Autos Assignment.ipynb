# %% [markdown]
# # Assignment on Auto dataset

# %%
#importing pandas and numpy
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1.Downloading the auto data set

# %%
# Downloading the autodata set
df = pd.read_csv('autos.csv')
df
# Out:
#      symboling         make fuel_type aspiration  num_of_doors   body_style  \
# 0            3  alfa-romero       gas        std             2  convertible
# 1            3  alfa-romero       gas        std             2  convertible
# 2            1  alfa-romero       gas        std             2    hatchback
# 3            2         audi       gas        std             4        sedan
# 4            2         audi       gas        std             4        sedan
# ..         ...          ...       ...        ...           ...          ...
# 188         -1        volvo       gas        std             4        sedan
# 189         -1        volvo       gas      turbo             4        sedan
# 190         -1        volvo       gas        std             4        sedan
# 191         -1        volvo    diesel      turbo             4        sedan
# 192         -1        volvo       gas      turbo             4        sedan
#
# ...

# %% [markdown]
# ### 2. Print out the first 8 entries

# %%
#printing the first 8 rows
df.head(8)
# Out:
#    symboling         make fuel_type aspiration  num_of_doors   body_style  \
# 0          3  alfa-romero       gas        std             2  convertible
# 1          3  alfa-romero       gas        std             2  convertible
# 2          1  alfa-romero       gas        std             2    hatchback
# 3          2         audi       gas        std             4        sedan
# 4          2         audi       gas        std             4        sedan
# 5          2         audi       gas        std             2        sedan
# 6          1         audi       gas        std             4        sedan
# 7          1         audi       gas        std             4        wagon
#
#   drive_wheels engine_location  wheel_base  length  ...  engine_size  \
# 0          rwd           front        88.6   168.8  ...          130
# 1          rwd           front        88.6   168.8  ...          130
# 2          rwd           front        94.5   171.2  ...          152
# ...

# %% [markdown]
# ### 3. Return a data frame containing the minimum price of each car

# %%
# Returning the dataframe of minimum prices of each car
gpd_a = df.groupby('make')
min_price = gpd_a['price'].min()
min_price
# Out:
# make
# alfa-romero      13495
# audi             13950
# bmw              16430
# chevrolet         5151
# dodge             5572
# honda             5399
# isuzu             6785
# jaguar           32250
# mazda             5195
# mercedes-benz    25552
# mercury          16503
# mitsubishi        5389
# nissan            5499
# peugot           11900
# plymouth          5572
# porsche          22018
# saab             11850
# subaru            5118
# toyota            5348
# volkswagen        7775
# volvo            12940
# Name: price, dtype: int64

# %% [markdown]
# ### 4. What is the smallest standard deviation of the prices?

# %%
std_dev = np.std(df).min()
std_dev
# Out:
# 0.2716780076438119

# %% [markdown]
# ### 5. Return the last 2 rows of each group of car make and fuel_type

# %%
col = ['make', 'fuel_type']
print(df[col].tail(2))
# Out:
#       make fuel_type
# 191  volvo    diesel
# 192  volvo       gas

# %% [markdown]
# ### 6. Replicate the Split-apply-combine without GroupBy

# %% [markdown]
# ### 7. Create 2 separate dictionaries and join them as a new dataset

# %%
dict_1 = {'make':['Alfa', 'benz', 'audi', 'saab'],'price':[25580, 56444, 36215,12548]}
dict_2 = {'make':['volvo', 'Toyota', 'vitz', 'nissan'], 'price':[38792, 478915, 897452,59864]}
df_1 = pd.DataFrame(dict_1)
df_2 = pd.DataFrame(dict_2)
merge_df = pd.concat([df_1, df_2],ignore_index=True)
merge_df
# Out:
#      make   price
# 0    Alfa   25580
# 1    benz   56444
# 2    audi   36215
# 3    saab   12548
# 4   volvo   38792
# 5  Toyota  478915
# 6    vitz  897452
# 7  nissan   59864
